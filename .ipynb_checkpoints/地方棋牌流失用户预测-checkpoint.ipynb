# %%
# %matplotlib inline 
#有了matplotlib inline 就可以省掉plt.show()了
# %load_ext autoreload
# %autoreload 2

from __future__ import division
from imports import *
#import pylab #使用pylab模式，可以直接使用numpy、pandas和绘图，而不需要再次引入,会配置为使用你所指定的matplotlib gui后端，还会提供一种更接近于matlab的界面
#%pylab
from IPython.display import display_html
display_html("""<button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">Toggle code</button>""", raw=True)
# 允许多行输出
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# 设置图像大小
from IPython.core.pylabtools import figsize
figsize(20,20)
# 不显示科学计数法
np.set_printoptions(suppress=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <button onclick="$('.input, .prompt, .output_stderr, .output_error').toggle();">Toggle code</button>

# %% [markdown]
# ## 定义问题
# > 运营需要对高价值用户中可能流失用户做定向运营，预防其流失，所以需要根据用户的行为，预测其是否可能流失
#
# #### 预测变量：
# 对近7日活跃的高价值用户（根据用户价值表中，分数为1~6的用户）预测其在未来7日内是否会流失
# #### 潜在分析变量（模型输入变量）：
# * 玩牌总时长 play_duration
# * 最近7日玩牌总时长 play_duration_7d
# * 最近30日玩牌总时长 play_duration_30d
# * 玩牌总局数 total_innings
# * 最近7日玩牌局数 innings_7d
# * 最近30日玩牌总局数 innings_30d
# * 付费次数 pay_count
# * 最近7日付费次数 pay_count_7d
# * 付费额度 pay_sum
# * 最近7日付费额度 pay_sum_7d
# * 破产次数 bankrupt_count
# * 最近7日破产次数 bankrupt_count_7d
# * 登录总次数 login_count
# * 最近7日登陆总次数 login_count_7d
# * 赢牌局数 win_innings
# * 最近7日赢牌局数 win_innings_7d
# * 输牌局数 lose_innings
# * 最近7日输牌局数 lose_innings_7d
# * 胜率 win_rate
# * 最近7日胜率 win_rate_7d
# * 生命周期 lifespan
# * 注册至今天数 signup_to_now_days
# * 总银币 total_silver_coin
# * 总金条 total_gold_bar
# * 携带银币数 carrying_silver_coin
# * 携带金条数 carrying_gold_bar
# * 保险箱银币数 safebox_silver_coin
# * 保险箱金条数 safebox_gold_coin
# * 比赛局数 match_innings
# * 比赛时长 match_duration
# * 比赛胜率 match_win_rate
# * 携带道具价值 carrying_items_value
# * VIP等级 vip_level
# * VIP剩余天数 vip_left_days
# * 领取救济次数 relieve_count
# * 领取救济总额 relieve_silver_coins
# * 最后活跃日期距离当前的天数 last_active_to_now_days
# * 最后付费日期距离当前的天数 last_pay_to_now_days
# * 最近连续登陆天数 recent_login_series_days
# * 最后玩牌输赢货币量 latest_play_coins

# %% [markdown]
# ## 抽取样本数据
# #### 取数建表：
# 1. 从用户价值表中取出分数在1~5之间的用户，为了消除地区差异，选取云南的用户，建表1
# 2. 将表1关联活跃表，选取出在前14日~前7日之间有活跃的用户，建表2
# 3. 将表2关联活跃表，标记出用户是否在前7日有活跃，建表3
# 4. 从表3中随机选取10000行，建表4
# 5. 将表4关联用户画像表、牌局中间表、付费中间表等，选取计算上面的指标，建表5

# %%
 # 表一
CREATE TABLE veda.fiona_7_4_1 AS
SELECT mid,
       label_score
FROM veda.fiona_dfqp_user_label
WHERE label_score >=1
  AND label_score <=6
  AND fplatformname = '云南'

# 表二
CREATE TABLE veda.fiona_7_4_2 AS
SELECT distinct a.mid,
       a.label_score
FROM veda.fiona_7_4_1 a
LEFT JOIN dim.user_act b ON a.mid = b.fuid
WHERE b.fbpid IN
    (SELECT fbpid
     FROM dim.bpid_map
     WHERE fgamename = '地方棋牌'
       AND fplatformname = '云南')
  AND b.dt >= '2018-06-18'
  AND b.dt <= '2018-06-24'
    
# 表三
CREATE TABLE veda.fiona_7_4_3 AS
SELECT DISTINCT a.mid,
                a.label_score,
                CASE
                    WHEN b.fuid IS NULL THEN 1
                    ELSE 0
                END AS Loss
FROM veda.fiona_7_4_2 a
LEFT JOIN
  (SELECT DISTINCT fuid
   FROM dim.user_act
   WHERE fbpid IN
       (SELECT fbpid
        FROM dim.bpid_map
        WHERE fgamename = '地方棋牌'
          AND fplatformname = '云南')
     AND dt >= '2018-06-25'
     AND dt <= '2018-07-01')b ON a.mid = b.fuid
    
# 表四
CREATE TABLE veda.fiona_7_4_4 AS
SELECT *
FROM veda.fiona_7_4_3
ORDER BY rand()
LIMIT 10000

# 表五
CREATE TABLE veda.fiona_7_4_5 AS WITH a1 AS
  (SELECT mid,
          play_duration,
          total_innings,
          pay_count,
          pay_sum,
          bankrupt_count,
          login_count,
          win_innings,
          lose_innings,
          round(win_innings/total_innings,2) AS win_rate,
          lifespan,
          signup_to_now_days,
          total_silver_coin,
          total_gold_bar,
          carrying_silver_coin,
          carrying_gold_bar,
          safebox_silver_coin,
          safebox_gold_bar,
          match_innings,
          match_duration,
          round(match_win_innings/match_innings,2) AS match_win_rate,
          carrying_items_value,
          vip_level,
          datediff('2018-06-24',vip_expire_time) AS vip_left_days,
          relieve_count,
          relieve_silver_coins,
          datediff('2018-06-24',substr(latest_login_time,1,10)) AS last_active_to_now_days,
          datediff('2018-06-24',substr(latest_pay_time,1,10)) AS last_pay_to_now_days,
          recent_login_series_days,
          latest_play_coins
   FROM veda.dfqp_user_portrait
   WHERE fplatformname = '云南'),
             a2 AS
  (SELECT fuid,
          play_duration AS play_duration_7d,
          play_innings AS innings_7d,
          pay_count AS pay_count_7d,
          pay_sum AS pay_sum_7d
   FROM veda.user_label_7day
   WHERE fgamename = '地方棋牌'
     AND fplatformname = '云南'
     AND dt = '2018-06-24'),
             a3 AS
  (SELECT fuid,
          play_duration AS play_duration_30d,
          play_innings AS innings_30d,
          pay_count AS pay_count_30d,
          pay_sum AS pay_sum_30d
   FROM veda.user_label_30day
   WHERE fgamename = '地方棋牌'
     AND fplatformname = '云南'
     AND dt = '2018-06-24'),
             a4 AS
  (SELECT fuid,
          count(1) AS bankrupt_count_7d
   FROM stage.user_bankrupt_stg
   WHERE fbpid IN
       (SELECT fbpid
        FROM dim.bpid_map
        WHERE fgamename = '地方棋牌'
          AND fplatformname = '云南')
     AND dt >= '2018-06-18'
     AND dt <= '2018-06-24'
   GROUP BY fuid),
             a5 AS
  (SELECT fuid,
          sum(flogin_cnt) AS login_count_7d
   FROM dim.user_act
   WHERE fbpid IN
       (SELECT fbpid
        FROM dim.bpid_map
        WHERE fgamename = '地方棋牌'
          AND fplatformname = '云南')
     AND dt >= '2018-06-18'
     AND dt <= '2018-06-24'
   GROUP BY fuid),
             a6 AS
  (SELECT fuid,
          sum(fwin_party_num) AS win_innings_7d,
          sum(flose_party_num) AS lose_innings_7d,
          round(sum(fwin_party_num)/sum(fparty_num),2) AS win_rate_7d
   FROM dim.user_gameparty
   WHERE fbpid IN
       (SELECT fbpid
        FROM dim.bpid_map
        WHERE fgamename = '地方棋牌'
          AND fplatformname = '云南')
     AND dt >= '2018-06-18'
     AND dt <= '2018-06-24'
   GROUP BY fuid)
SELECT b.mid,
       b.label_score,
       b.loss,
       a1.play_duration,
       a1.total_innings,
       a1.pay_count,
       a1.pay_sum,
       a1.bankrupt_count,
       a1.login_count,
       a1.win_innings,
       a1.lose_innings,
       a1.win_rate,
       a1.lifespan,
       a1.signup_to_now_days,
       a1.total_silver_coin,
       a1.total_gold_bar,
       a1.carrying_silver_coin,
       a1.carrying_gold_bar,
       a1.safebox_silver_coin,
       a1.safebox_gold_bar,
       a1.match_innings,
       a1.match_duration,
       a1.match_win_rate,
       a1.carrying_items_value,
       a1.vip_level,
       a1.vip_left_days,
       a1.relieve_count,
       a1.relieve_silver_coins,
       a1.last_active_to_now_days,
       a1.last_pay_to_now_days,
       a1.recent_login_series_days,
       a1.latest_play_coins,
       a2.play_duration_7d,
       a2.innings_7d,
       a2.pay_count_7d,
       a2.pay_sum_7d,
       a3.play_duration_30d,
       a3.innings_30d,
       a3.pay_count_30d,
       a3.pay_sum_30d,
       a4.bankrupt_count_7d,
       a5.login_count_7d,
       a6.win_innings_7d,
       a6.lose_innings_7d,
       a6.win_rate_7d
FROM veda.fiona_7_4_4 b
LEFT JOIN a1 ON b.mid = a1.mid
LEFT JOIN a2 ON b.mid = a2.fuid
LEFT JOIN a3 ON b.mid = a3.fuid
LEFT JOIN a4 ON b.mid = a4.fuid
LEFT JOIN a5 ON b.mid = a5.fuid
LEFT JOIN a6 ON b.mid = a6.fuid
# Out:
#   File "<ipython-input-4-1c23bbcf5e51>", line 2
#     CREATE TABLE veda.fiona_7_4_1 AS
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 理解数据

# %%
path = './csvs/user_lose_predict.csv'
columns = ['mid',
'label_score',
'loss',
'play_duration',
'total_innings',
'pay_count',
'pay_sum',
'bankrupt_count',
'login_count',
'win_innings',
'lose_innings',
'win_rate',
'lifespan',
'signup_to_now_days',
'total_silver_coin',
'total_gold_bar',
'carrying_silver_coin',
'carrying_gold_bar',
'safebox_silver_coin',
'safebox_gold_bar',
'match_innings',
'match_duration',
'match_win_rate',
'carrying_items_value',
'vip_level',
'vip_left_days',
'relieve_count',
'relieve_silver_coins',
'last_active_to_now_days',
'last_pay_to_now_days',
'recent_login_series_days',
'latest_play_coins',
'play_duration_7d',
'innings_7d',
'pay_count_7d',
'pay_sum_7d',
'play_duration_30d',
'innings_30d',
'pay_count_30d',
'pay_sum_30d',
'bankrupt_count_7d',
'login_count_7d',
'win_innings_7d',
'lose_innings_7d',
'win_rate_7d']
fiona_file1 = pd.read_csv(path,names=columns,skiprows=1)
fiona_file1.head(10)
fiona_file1.groupby('loss').size()
pd.set_option('precision',1)
fiona_file1.describe()
# Out:
#        mid  label_score  loss  play_duration  total_innings  pay_count  \
# 0  3746580            3     0        1217000          12889        339
# 1  3998689            5     0         144786           3488         28
# 2  4236694            6     0         779098           5920          0
# 3  4274127            6     0        3892858          32386          3
# 4  4299875            6     0         964682          11644          0
# 5  4313323            6     0         758985          16178          0
# 6  4315578            6     0        4363992          45383          0
# 7  4341244            3     0        2261689          50480          9
# 8  4356086            6     0        2016795          17354          0
# 9  4357644            6     0         548186          10919          2
#
#    pay_sum  bankrupt_count  login_count  win_innings     ...       pay_sum_7d  \
# 0    181.5            1247         1691         5651     ...              0.0
# 1    115.0             275          272         1609     ...              0.5
# 2      0.0              19          759         2979     ...              0.0
# 3      6.0             121         2889         8231     ...              0.0
# 4      0.0             124         1628         3809     ...              0.0
# 5      0.0              64         1578         6153     ...              0.0
# 6      0.0               2         2709        11991     ...              0.0
# 7     22.0              95         1227         7877     ...              0.0
# 8      0.0              86         1760         5653     ...              0.0
# 9      1.0             670         1012         4707     ...              0.0
#
#    play_duration_30d  innings_30d  pay_count_30d  pay_sum_30d  \
# 0             5916.0         62.0            0.0          0.0
# 1              926.0          8.0            1.0          0.5
# 2             1329.0         10.0            0.0          0.0
# 3           262117.0       2157.0            0.0          0.0
# 4            11573.0        122.0            0.0          0.0
# 5             2834.0         18.0            0.0          0.0
# 6            54358.0        577.0            0.0          0.0
# 7            27492.0        491.0            0.0          0.0
# 8            70299.0        583.0            0.0          0.0
# 9            13368.0        200.0            2.0          1.0
#
#    bankrupt_count_7d  login_count_7d  win_innings_7d  lose_innings_7d  \
# 0                2.0               4             5.0             11.0
# 1                3.0               5             2.0              5.0
# 2                NaN               5             3.0              3.0
# 3                NaN              82            79.0            222.0
# 4                NaN              14             2.0              5.0
# 5                NaN               8             0.0              0.0
# 6                NaN              55            95.0            250.0
# 7                NaN              35           105.0            112.0
# 8                NaN              20            12.0             36.0
# 9                2.0              12             1.0              6.0
#
#    win_rate_7d
# 0          0.3
# 1          0.2
# 2          0.5
# 3          0.2
# 4          0.3
# 5          0.0
# 6          0.3
# 7          0.4
# 8          0.2
# 9          0.1
#
# [10 rows x 45 columns]
# loss
# 0    8536
# 1    1464
# dtype: int64
#            mid  label_score     loss  play_duration  total_innings  pay_count  \
# count  1.0e+04      10000.0  10000.0        1.0e+04        10000.0    10000.0
# mean   1.2e+07          4.9      0.1        9.6e+05        11639.0       22.3
# std    5.9e+06          1.3      0.4        8.4e+05         9971.6       58.0
# min    3.2e+06          1.0      0.0        2.5e+04          396.0        0.0
# 25%    6.9e+06          3.0      0.0        3.9e+05         5675.0        0.0
# 50%    1.1e+07          5.0      0.0        7.6e+05         9273.5        7.0
# 75%    1.9e+07          6.0      0.0        1.2e+06        14760.5       22.0
# max    2.1e+07          6.0      1.0        8.5e+06       192578.0     2047.0
#
#        pay_sum  bankrupt_count  login_count  win_innings     ...       \
# count  10000.0         10000.0      10000.0      10000.0     ...
# mean      69.7           322.1        959.0       4444.8     ...
# std      322.2           417.8        695.5       3849.9     ...
# min        0.0             0.0         27.0          4.0     ...
# 25%        0.0            71.0        470.0       2022.0     ...
# 50%       14.0           193.0        814.0       3507.0     ...
# 75%       44.5           428.0       1280.0       5663.2     ...
# max    13539.0          9088.0       8701.0      74522.0     ...
#
#        pay_sum_7d  play_duration_30d  innings_30d  pay_count_30d  pay_sum_30d  \
# count      9422.0             9783.0       9783.0         9783.0       9783.0
# mean          1.0            70305.6        764.0            1.7          4.2
# std           7.9            86303.8        897.3            8.1         32.0
# min           0.0               22.0          1.0            0.0          0.0
# 25%           0.0            13641.0        161.0            0.0          0.0
# 50%           0.0            41564.0        480.0            0.0          0.0
# 75%           0.0            93073.5       1034.0            0.0          0.0
# max         270.0           934134.0       9220.0          243.0       1900.0
#
#        bankrupt_count_7d  login_count_7d  win_innings_7d  lose_innings_7d  \
# count             4683.0         10000.0          9422.0           9422.0
# mean                 9.6            35.4            70.8            100.9
# std                 15.1            41.2            92.3            138.8
# min                  1.0             0.0             0.0              0.0
# 25%                  2.0             8.0            11.0             16.0
# 50%                  6.0            22.0            40.0             53.0
# 75%                 12.0            49.0            95.0            127.0
# max                618.0           470.0          1461.0           1598.0
#
#        win_rate_7d
# count       9422.0
# mean           0.4
# std            0.1
# min            0.0
# 25%            0.3
# 50%            0.4
# 75%            0.5
# max            1.0
#
# [8 rows x 45 columns]

# %% [markdown]
# ## 将负值转换为正值

# %%
fiona_file1 = abs(fiona_file1)

# %% [markdown]
# ## Null值转换

# %%
# 先查看有多少null值
fiona_null = fiona_file1.shape[0] - fiona_file1.count()
fiona_null_percent = (fiona_null/fiona_file1.shape[0])*100 
fiona_null_percent
# Out:
# mid                           0.0
# label_score                   0.0
# loss                          0.0
# play_duration                 0.0
# total_innings                 0.0
# pay_count                     0.0
# pay_sum                       0.0
# bankrupt_count                0.0
# login_count                   0.0
# win_innings                   0.0
# lose_innings                  0.0
# win_rate                      0.0
# lifespan                      0.0
# signup_to_now_days            0.0
# total_silver_coin             0.0
# total_gold_bar                0.0
# carrying_silver_coin          0.0
# carrying_gold_bar             0.0
# safebox_silver_coin           0.0
# safebox_gold_bar              0.0
# match_innings                 0.0
# match_duration                0.0
# match_win_rate                9.6
# carrying_items_value        100.0
# vip_level                   100.0
# vip_left_days                83.9
# relieve_count                 0.0
# relieve_silver_coins          0.0
# last_active_to_now_days       0.0
# last_pay_to_now_days         29.7
# recent_login_series_days      0.0
# latest_play_coins             0.3
# play_duration_7d              5.8
# innings_7d                    5.8
# pay_count_7d                  5.8
# pay_sum_7d                    5.8
# play_duration_30d             2.2
# innings_30d                   2.2
# pay_count_30d                 2.2
# pay_sum_30d                   2.2
# bankrupt_count_7d            53.2
# login_count_7d                0.0
# win_innings_7d                5.8
# lose_innings_7d               5.8
# win_rate_7d                   5.8
# dtype: float64

# %%
# carring_items_values 和vip_level字段 全是null，发现获取不到这两个字段，业务端没有上报
# 删除carring_items_values 和vip_level字段
fiona_file1.drop(['carrying_items_value','vip_level'],axis=1,inplace=True)

# %% [markdown]
# #### 可见，vip_left_days 有83.9%的缺失值，通过经验表示，假如用户没有购买vip的话，这个字段就会是null，所以处理办法是设置为0
# #### bankrupt_count_7d（近7日内破产次数） 有53.2%的缺失值，为null的话表示，用户在7日内没有破产，那么我们处理这个字段的null为0
# #### match_win_rate（比赛胜率）有9.6%的null值，因为有的用户不参加比赛，那么自然就没有比赛胜率，所以处理办法是设置为0
# #### 其余字段的null值和比赛的类似，所以统统直接设置为0

# %%
fiona_file1.fillna(0,inplace=True)

# %%
# 检查一遍
fiona_null = fiona_file1.shape[0] - fiona_file1.count()
fiona_null_percent = (fiona_null/fiona_file1.shape[0])*100 
fiona_null_percent
# Out:
# mid                         0.0
# label_score                 0.0
# loss                        0.0
# play_duration               0.0
# total_innings               0.0
# pay_count                   0.0
# pay_sum                     0.0
# bankrupt_count              0.0
# login_count                 0.0
# win_innings                 0.0
# lose_innings                0.0
# win_rate                    0.0
# lifespan                    0.0
# signup_to_now_days          0.0
# total_silver_coin           0.0
# total_gold_bar              0.0
# carrying_silver_coin        0.0
# carrying_gold_bar           0.0
# safebox_silver_coin         0.0
# safebox_gold_bar            0.0
# match_innings               0.0
# match_duration              0.0
# match_win_rate              0.0
# vip_left_days               0.0
# relieve_count               0.0
# relieve_silver_coins        0.0
# last_active_to_now_days     0.0
# last_pay_to_now_days        0.0
# recent_login_series_days    0.0
# latest_play_coins           0.0
# play_duration_7d            0.0
# innings_7d                  0.0
# pay_count_7d                0.0
# pay_sum_7d                  0.0
# play_duration_30d           0.0
# innings_30d                 0.0
# pay_count_30d               0.0
# pay_sum_30d                 0.0
# bankrupt_count_7d           0.0
# login_count_7d              0.0
# win_innings_7d              0.0
# lose_innings_7d             0.0
# win_rate_7d                 0.0
# dtype: float64

# %%
pd.set_option('precision',1)
# 查看数据的皮尔逊相关系数
pearson = DataFrame(fiona_file1.corr(method='pearson'))
# 绝对值大于0.7的表示有强关联关系
a = pearson[abs(pearson) >= 0.7]
index = a.index[np.where(pd.notnull(a))[0]]
columns = a.columns[np.where(pd.notnull(a))[1]]
names = index+','+columns
#print(pearson)
pd.Series(names)
# Out:
# 0                                  mid,mid
# 1                             mid,lifespan
# 2                   mid,signup_to_now_days
# 3                  label_score,label_score
# 4                                loss,loss
# 5              play_duration,play_duration
# 6              play_duration,total_innings
# 7                play_duration,login_count
# 8                play_duration,win_innings
# 9               play_duration,lose_innings
# 10            play_duration,match_duration
# 11             total_innings,play_duration
# 12             total_innings,total_innings
# 13               total_innings,login_count
# 14               total_innings,win_innings
# 15              total_innings,lose_innings
# 16             total_innings,match_innings
# 17            total_innings,match_duration
# 18                     pay_count,pay_count
# 19                         pay_sum,pay_sum
# 20           bankrupt_count,bankrupt_count
# 21            bankrupt_count,relieve_count
# 22     bankrupt_count,relieve_silver_coins
# 23               login_count,play_duration
# 24               login_count,total_innings
# 25                 login_count,login_count
# 26                 login_count,win_innings
# 27                login_count,lose_innings
# 28              login_count,match_duration
# 29               win_innings,play_duration
#                       ...
# 99      play_duration_30d,play_duration_7d
# 100           play_duration_30d,innings_7d
# 101    play_duration_30d,play_duration_30d
# 102          play_duration_30d,innings_30d
# 103      play_duration_30d,lose_innings_7d
# 104           innings_30d,play_duration_7d
# 105                 innings_30d,innings_7d
# 106          innings_30d,play_duration_30d
# 107                innings_30d,innings_30d
# 108             innings_30d,win_innings_7d
# 109            innings_30d,lose_innings_7d
# 110             pay_count_30d,pay_count_7d
# 111            pay_count_30d,pay_count_30d
# 112                pay_sum_30d,pay_sum_30d
# 113    bankrupt_count_7d,bankrupt_count_7d
# 114          login_count_7d,login_count_7d
# 115          login_count_7d,win_innings_7d
# 116        win_innings_7d,play_duration_7d
# 117              win_innings_7d,innings_7d
# 118             win_innings_7d,innings_30d
# 119          win_innings_7d,login_count_7d
# 120          win_innings_7d,win_innings_7d
# 121         win_innings_7d,lose_innings_7d
# 122       lose_innings_7d,play_duration_7d
# 123             lose_innings_7d,innings_7d
# 124      lose_innings_7d,play_duration_30d
# 125            lose_innings_7d,innings_30d
# 126         lose_innings_7d,win_innings_7d
# 127        lose_innings_7d,lose_innings_7d
# 128                win_rate_7d,win_rate_7d
# Length: 129, dtype: object

# %% [markdown]
# #### 可以看出，有43种强关联关系的变量组
# 例如，是否流失与最后一次活跃距离当前的天数有强相关性
# 玩牌时长与玩牌局数
# 登录次数与玩牌局数等
# 基本与我们的认知是相符合的

# %%
# 查看一下每个指标的直方图
fiona_file1.hist(sharex=False,sharey=False,xlabelsize=1,ylabelsize=1);

# %% [markdown]
# #### 可以看出有的指标呈指数分布，例如破产次数、玩牌局数、登录次数、玩牌时长、领取救济次数、领取救济金额
# #### 胜率呈类高斯分布

# %%
fiona_file1.plot(kind='box',subplots=True,layout=(8,6),sharex=False,sharey=False,fontsize=8);

# %%
fiona_file1.plot(kind='kde',subplots=True,layout=(8,6),sharex=False,sharey=False,use_index=False);

# %%
scatter_matrix(fiona_file1);

# %%
# 关系矩阵图
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(fiona_file1.corr());
fig.colorbar(cax)

# %% [markdown]
# ## 数据特征选定

# %%
# 从关系矩阵图中看出，有不少变量之间的相关性较高，我们通过卡方检验，筛选出10个对结果影响最大的数据特征
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE 
from scipy.stats import pearsonr
# 将数据分为输入数据和输出结果
array= fiona_file1.values
X = array[:,3:41].astype(np.float32)
y = array[:,2]
# 调整数据尺度
transformer = MinMaxScaler(feature_range=(0,1))
newX = transformer.fit_transform(X)
# 特征选定
test = SelectKBest(k=10)
fit = test.fit(X,y)
set_printoptions(precision=3)
#fit.transform(X)
a = Series(fit.scores_)
b = fiona_file1.iloc[:,3:41].columns
c = Series(b,a)
print(c.sort_index(ascending=False))
# Out:
# 5.7e+03     last_active_to_now_days
# 8.0e+02              login_count_7d
# 6.0e+02                 innings_30d
# 6.0e+02                  innings_7d
# 6.0e+02              win_innings_7d
# 5.9e+02           play_duration_30d
# 5.9e+02            play_duration_7d
# 4.3e+02                 login_count
# 3.7e+02               play_duration
# 3.4e+02               vip_left_days
# 2.4e+02               total_innings
# 2.4e+02                 win_innings
# 2.2e+02    recent_login_series_days
# 2.0e+02                lose_innings
# 1.5e+02        last_pay_to_now_days
# 1.1e+02           bankrupt_count_7d
# 1.0e+02              match_duration
# 5.5e+01               relieve_count
# 5.5e+01        relieve_silver_coins
# 4.8e+01               match_innings
# 3.3e+01              bankrupt_count
# 2.2e+01                pay_count_7d
# 2.0e+01          signup_to_now_days
# 1.5e+01               pay_count_30d
# 1.0e+01                  pay_sum_7d
# 9.8e+00                 pay_sum_30d
# 9.5e+00           total_silver_coin
# 9.4e+00         safebox_silver_coin
# 5.4e+00            safebox_gold_bar
# 4.8e+00                    lifespan
# 4.5e+00              total_gold_bar
# 1.7e+00           carrying_gold_bar
# 1.5e+00        carrying_silver_coin
# 1.4e+00                    win_rate
# 7.1e-01              match_win_rate
# 4.6e-01                   pay_count
# 1.1e-01           latest_play_coins
# 1.1e-02                     pay_sum
# dtype: object

# %% [markdown]
# ## 删除相关性较弱的字段

# %%
fiona_file2 = fiona_file1.drop(['relieve_count','relieve_silver_coins','match_innings','bankrupt_count','pay_count_7d','signup_to_now_days','pay_count_30d','pay_sum_7d','pay_sum_30d','total_silver_coin','safebox_silver_coin','safebox_gold_bar','lifespan','total_gold_bar','carrying_gold_bar','carrying_silver_coin','win_rate','match_win_rate','pay_count','latest_play_coins','pay_sum'],axis=1)
fiona_file2.dtypes
# Out:
# mid                         float64
# label_score                 float64
# loss                        float64
# play_duration               float64
# total_innings               float64
# login_count                 float64
# win_innings                 float64
# lose_innings                float64
# match_duration              float64
# vip_left_days               float64
# last_active_to_now_days     float64
# last_pay_to_now_days        float64
# recent_login_series_days    float64
# play_duration_7d            float64
# innings_7d                  float64
# play_duration_30d           float64
# innings_30d                 float64
# bankrupt_count_7d           float64
# login_count_7d              float64
# win_innings_7d              float64
# lose_innings_7d             float64
# win_rate_7d                 float64
# dtype: object

# %%
# 将数据分为输入数据和输出结果
array= fiona_file2.values
X = array[:,3:19].astype(np.float32)
y = array[:,2]
# 调整数据尺度
transformer = MinMaxScaler(feature_range=(0,1))
newX = transformer.fit_transform(X)
# 特征选定
test = SelectKBest(k=10)
fit = test.fit(X,y)
set_printoptions(precision=3)
#fit.transform(X)
a = Series(fit.scores_)
b = fiona_file2.iloc[:,3:19].columns
c = Series(b,a)
print(c.sort_index(ascending=False))
# Out:
# 5677.1     last_active_to_now_days
# 798.3               login_count_7d
# 604.9                  innings_30d
# 601.7                   innings_7d
# 592.6            play_duration_30d
# 592.5             play_duration_7d
# 429.3                  login_count
# 372.3                play_duration
# 339.7                vip_left_days
# 244.9                total_innings
# 239.8                  win_innings
# 222.1     recent_login_series_days
# 203.3                 lose_innings
# 150.4         last_pay_to_now_days
# 113.5            bankrupt_count_7d
# 102.6               match_duration
# dtype: object

# %%
pd.set_option('precision',1)
# 查看数据的皮尔逊相关系数
pearson = DataFrame(fiona_file2.corr(method='pearson'))
# 绝对值大于0.7的表示有强关联关系
a = pearson[abs(pearson) >= 0.7]
index = a.index[np.where(pd.notnull(a))[0]]
columns = a.columns[np.where(pd.notnull(a))[1]]
names = index+','+columns
#print(pearson)
pd.Series(names)
# Out:
# 0                                 mid,mid
# 1                 label_score,label_score
# 2                               loss,loss
# 3             play_duration,play_duration
# 4             play_duration,total_innings
# 5               play_duration,login_count
# 6               play_duration,win_innings
# 7              play_duration,lose_innings
# 8            play_duration,match_duration
# 9             total_innings,play_duration
# 10            total_innings,total_innings
# 11              total_innings,login_count
# 12              total_innings,win_innings
# 13             total_innings,lose_innings
# 14           total_innings,match_duration
# 15              login_count,play_duration
# 16              login_count,total_innings
# 17                login_count,login_count
# 18                login_count,win_innings
# 19               login_count,lose_innings
# 20             login_count,match_duration
# 21              win_innings,play_duration
# 22              win_innings,total_innings
# 23                win_innings,login_count
# 24                win_innings,win_innings
# 25               win_innings,lose_innings
# 26             win_innings,match_duration
# 27             lose_innings,play_duration
# 28             lose_innings,total_innings
# 29               lose_innings,login_count
#                      ...
# 52                 innings_7d,innings_30d
# 53              innings_7d,win_innings_7d
# 54             innings_7d,lose_innings_7d
# 55     play_duration_30d,play_duration_7d
# 56           play_duration_30d,innings_7d
# 57    play_duration_30d,play_duration_30d
# 58          play_duration_30d,innings_30d
# 59      play_duration_30d,lose_innings_7d
# 60           innings_30d,play_duration_7d
# 61                 innings_30d,innings_7d
# 62          innings_30d,play_duration_30d
# 63                innings_30d,innings_30d
# 64             innings_30d,win_innings_7d
# 65            innings_30d,lose_innings_7d
# 66    bankrupt_count_7d,bankrupt_count_7d
# 67          login_count_7d,login_count_7d
# 68          login_count_7d,win_innings_7d
# 69        win_innings_7d,play_duration_7d
# 70              win_innings_7d,innings_7d
# 71             win_innings_7d,innings_30d
# 72          win_innings_7d,login_count_7d
# 73          win_innings_7d,win_innings_7d
# 74         win_innings_7d,lose_innings_7d
# 75       lose_innings_7d,play_duration_7d
# 76             lose_innings_7d,innings_7d
# 77      lose_innings_7d,play_duration_30d
# 78            lose_innings_7d,innings_30d
# 79         lose_innings_7d,win_innings_7d
# 80        lose_innings_7d,lose_innings_7d
# 81                win_rate_7d,win_rate_7d
# Length: 82, dtype: object

# %%
# 关系矩阵图
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(fiona_file1.corr());
ax.set_xticklabels(fiona_file2.columns)
ax.set_yticklabels(fiona_file2.columns)
fig.colorbar(cax)
# Out:
# [Text(0,1,'mid'),
#  Text(0,1,'label_score'),
#  Text(0,1,'loss'),
#  Text(0,1,'play_duration'),
#  Text(0,1,'total_innings'),
#  Text(0,1,'login_count'),
#  Text(0,1,'win_innings'),
#  Text(0,1,'lose_innings'),
#  Text(0,1,'match_duration'),
#  Text(0,1,'vip_left_days'),
#  Text(0,1,'last_active_to_now_days')]
# [Text(0,0,'mid'),
#  Text(0,0,'label_score'),
#  Text(0,0,'loss'),
#  Text(0,0,'play_duration'),
#  Text(0,0,'total_innings'),
#  Text(0,0,'login_count'),
#  Text(0,0,'win_innings'),
#  Text(0,0,'lose_innings'),
#  Text(0,0,'match_duration'),
#  Text(0,0,'vip_left_days'),
#  Text(0,0,'last_active_to_now_days')]

# %%
# 将数据分为输入数据和输出结果
array= fiona_file2.values
X = array[:,3:19].astype(np.float32)
y = array[:,2]

# %% [markdown]
# ## 分离数据集

# %%
validation_size = 0.2
seed = 7
X_train,X_validation,y_train,y_validation = train_test_split(X,y,test_size=validation_size,random_state=seed)

# %% [markdown]
# ## 评估算法

# %%
# 通过分类准确度来评估算法
num_folds = 10
scoring = 'accuracy'

## 算法
models = {}
# 逻辑回归
models['LR'] = LogisticRegression()
# 线性判别分析
models['LDA'] = LinearDiscriminantAnalysis()
# K近邻
models['KNN'] = KNeighborsClassifier()
# 分类与回归树
models['CART'] = DecisionTreeClassifier()
# 贝叶斯分类器
models['NB'] = GaussianNB()
# 支持向量机
models['SVM'] = SVC()

results = []
for key in models:
    kfold = KFold(n_splits=num_folds,random_state=seed)
    cv_results = cross_val_score(models[key],X_train,y_train,cv=kfold,scoring=scoring)
    results.append(cv_results)
    print('%s: %f (%f)'% (key,cv_results.mean(),cv_results.std()))
# Out:
# KNN: 0.847500 (0.009236)
# LDA: 0.879750 (0.013285)
# SVM: 0.854000 (0.009598)
# NB: 0.558000 (0.013337)
# CART: 0.866625 (0.009938)
# LR: 0.861000 (0.008729)

# %%
# 通过箱线图显示数据的分布情况
fig = plt.figure()
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(models.keys())
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x211e6e30>,
#   <matplotlib.lines.Line2D at 0x211effd0>,
#   <matplotlib.lines.Line2D at 0x211eff70>,
#   <matplotlib.lines.Line2D at 0x211ff250>,
#   <matplotlib.lines.Line2D at 0x233db4d0>,
#   <matplotlib.lines.Line2D at 0x233e3750>],
#  'caps': [<matplotlib.lines.Line2D at 0x211ef510>,
#   <matplotlib.lines.Line2D at 0x211ef7b0>,
#   <matplotlib.lines.Line2D at 0x211f87d0>,
#   <matplotlib.lines.Line2D at 0x211f8a70>,
#   <matplotlib.lines.Line2D at 0x211ffa50>,
#   <matplotlib.lines.Line2D at 0x211ffcf0>,
#   <matplotlib.lines.Line2D at 0x233dbcd0>,
#   <matplotlib.lines.Line2D at 0x233dbf70>,
#   <matplotlib.lines.Line2D at 0x233e3f50>,
#   <matplotlib.lines.Line2D at 0x233e3f70>,
#   <matplotlib.lines.Line2D at 0x233ecf50>,
#   <matplotlib.lines.Line2D at 0x233f6490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x211efcf0>,
#   <matplotlib.lines.Line2D at 0x211f8fb0>,
#   <matplotlib.lines.Line2D at 0x211fffb0>,
#   <matplotlib.lines.Line2D at 0x233e34d0>,
#   <matplotlib.lines.Line2D at 0x233ec750>,
#   <matplotlib.lines.Line2D at 0x233f69d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x211efa50>,
#   <matplotlib.lines.Line2D at 0x211f8d10>,
#   <matplotlib.lines.Line2D at 0x211fff90>,
#   <matplotlib.lines.Line2D at 0x233dbf90>,
#   <matplotlib.lines.Line2D at 0x233ec4b0>,
#   <matplotlib.lines.Line2D at 0x233f6730>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x211e6f10>,
#   <matplotlib.lines.Line2D at 0x211e6f30>,
#   <matplotlib.lines.Line2D at 0x211efff0>,
#   <matplotlib.lines.Line2D at 0x211f8530>,
#   <matplotlib.lines.Line2D at 0x211ff510>,
#   <matplotlib.lines.Line2D at 0x211ff7b0>,
#   <matplotlib.lines.Line2D at 0x233db790>,
#   <matplotlib.lines.Line2D at 0x233dba30>,
#   <matplotlib.lines.Line2D at 0x233e3a10>,
#   <matplotlib.lines.Line2D at 0x233e3cb0>,
#   <matplotlib.lines.Line2D at 0x233ecc90>,
#   <matplotlib.lines.Line2D at 0x233ecf30>]}
# [Text(0,0,'KNN'),
#  Text(0,0,'LDA'),
#  Text(0,0,'SVM'),
#  Text(0,0,'NB'),
#  Text(0,0,'CART'),
#  Text(0,0,'LR')]

# %%
# 可能由于数据分布的不均导致算法不够准确
# 于是将数据进行正态化处理
pipelines = {}
pipelines['ScalerLR'] = Pipeline([('Scaler',StandardScaler()),('LR',LogisticRegression())])
pipelines['ScalerLDA'] = Pipeline([('Scaler',StandardScaler()),('LDA',LinearDiscriminantAnalysis())])
pipelines['ScalerKNN'] = Pipeline([('Scaler',StandardScaler()),('KNN',KNeighborsClassifier())])
pipelines['ScalerCART'] = Pipeline([('Scaler',StandardScaler()),('CART',DecisionTreeClassifier())])
#pipelines['ScalerNB'] = Pipeline([('Scaler',StandardScaler()),('NB',GaussianNB)])
pipelines['ScalerSVM'] = Pipeline([('Scaler',StandardScaler()),('SVM',SVC())])

results = []
for key in pipelines:
    kfold = KFold(n_splits=num_folds,random_state=seed)
    cv_results = cross_val_score(pipelines[key],X_train,y_train,cv=kfold,scoring=scoring)
    results.append(cv_results)
    print('%s: %f (%f)'%(key,cv_results.mean(),cv_results.std()))
# Out:
# ScalerLDA: 0.879750 (0.013285)
# ScalerCART: 0.864250 (0.010265)
# ScalerKNN: 0.883375 (0.006048)
# ScalerLR: 0.890750 (0.012186)
# ScalerSVM: 0.897125 (0.010063)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
axe = ax.boxplot(results)
ax.set_xticklabels(pipelines.keys())
# Out:
# [Text(0,0,'ScalerLDA'),
#  Text(0,0,'ScalerCART'),
#  Text(0,0,'ScalerKNN'),
#  Text(0,0,'ScalerLR'),
#  Text(0,0,'ScalerSVM')]

# %% [markdown]
# ## 使用集成算法

# %%
# 集成算法
ensembles = {}
ensembles['ScaledAB'] = Pipeline([('Scaler',StandardScaler()),('AB',AdaBoostClassifier())])
ensembles['ScaledGBM'] = Pipeline([('Scaler',StandardScaler()),('GBM',GradientBoostingClassifier())])
ensembles['ScaledRF'] = Pipeline([('Scaler',StandardScaler()),('RFR',RandomForestClassifier())])
ensembles['ScaledET'] = Pipeline([('Scaler',StandardScaler()),('ETR',ExtraTreesClassifier())])
results = []
for key in ensembles:
    kfold = KFold(n_splits=num_folds,random_state=seed)
    cv_result = cross_val_score(ensembles[key],X_train,y_train,cv=kfold,scoring=scoring)
    results.append(cv_result)
    print('%s: %f (%f)'% (key,cv_result.mean(),cv_result.std()))
# Out:
# ScaledET: 0.892250 (0.007241)
# ScaledAB: 0.903625 (0.011625)
# ScaledRF: 0.896125 (0.005848)
# ScaledGBM: 0.901750 (0.010112)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(ensembles.keys())
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1ffeae90>,
#   <matplotlib.lines.Line2D at 0x18792fb0>,
#   <matplotlib.lines.Line2D at 0x18792f90>,
#   <matplotlib.lines.Line2D at 0x187a5250>],
#  'caps': [<matplotlib.lines.Line2D at 0x18792530>,
#   <matplotlib.lines.Line2D at 0x187927d0>,
#   <matplotlib.lines.Line2D at 0x1879c7d0>,
#   <matplotlib.lines.Line2D at 0x1879ca70>,
#   <matplotlib.lines.Line2D at 0x187a5a50>,
#   <matplotlib.lines.Line2D at 0x187a5cf0>,
#   <matplotlib.lines.Line2D at 0x187aecd0>,
#   <matplotlib.lines.Line2D at 0x187aef70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18792d10>,
#   <matplotlib.lines.Line2D at 0x1879cfb0>,
#   <matplotlib.lines.Line2D at 0x187a5fb0>,
#   <matplotlib.lines.Line2D at 0x187b54d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x18792a70>,
#   <matplotlib.lines.Line2D at 0x1879cd10>,
#   <matplotlib.lines.Line2D at 0x187a5f90>,
#   <matplotlib.lines.Line2D at 0x187aef90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1ffeaf90>,
#   <matplotlib.lines.Line2D at 0x1ffeafb0>,
#   <matplotlib.lines.Line2D at 0x18792ff0>,
#   <matplotlib.lines.Line2D at 0x1879c530>,
#   <matplotlib.lines.Line2D at 0x187a5510>,
#   <matplotlib.lines.Line2D at 0x187a57b0>,
#   <matplotlib.lines.Line2D at 0x187ae790>,
#   <matplotlib.lines.Line2D at 0x187aea30>]}
# [Text(0,0,'ScaledET'),
#  Text(0,0,'ScaledAB'),
#  Text(0,0,'ScaledRF'),
#  Text(0,0,'ScaledGBM')]

# %% [markdown]
# ## 我们再选用全部字段做预测试试

# %%
# 将数据分为输入数据和输出结果
array= fiona_file1.values
X1 = array[:,3:41].astype(np.float32)
y1 = array[:,2]
validation_size = 0.2
seed = 7
X_train1,X_validation1,y_train1,y_validation1 = train_test_split(X1,y1,test_size=validation_size,random_state=seed)
# 通过分类准确度来评估算法
num_folds = 10
scoring = 'accuracy'

## 算法
models = {}
# 逻辑回归
models['LR'] = LogisticRegression()
# 线性判别分析
models['LDA'] = LinearDiscriminantAnalysis()
# K近邻
models['KNN'] = KNeighborsClassifier()
# 分类与回归树
models['CART'] = DecisionTreeClassifier()
# 贝叶斯分类器
models['NB'] = GaussianNB()
# 支持向量机
models['SVM'] = SVC()

results = []
for key in models:
    kfold = KFold(n_splits=num_folds,random_state=seed)
    cv_results = cross_val_score(models[key],X_train1,y_train1,cv=kfold,scoring=scoring)
    results.append(cv_results)
    print('%s: %f (%f)'% (key,cv_results.mean(),cv_results.std()))
    
# 集成算法
ensembles = {}
ensembles['ScaledAB'] = Pipeline([('Scaler',StandardScaler()),('AB',AdaBoostClassifier())])
ensembles['ScaledGBM'] = Pipeline([('Scaler',StandardScaler()),('GBM',GradientBoostingClassifier())])
ensembles['ScaledRF'] = Pipeline([('Scaler',StandardScaler()),('RFR',RandomForestClassifier())])
ensembles['ScaledET'] = Pipeline([('Scaler',StandardScaler()),('ETR',ExtraTreesClassifier())])
results = []
for key in ensembles:
    kfold = KFold(n_splits=num_folds,random_state=seed)
    cv_result = cross_val_score(ensembles[key],X_train,y_train,cv=kfold,scoring=scoring)
    results.append(cv_result)
    print('%s: %f (%f)'% (key,cv_result.mean(),cv_result.std()))
# Out:
# KNN: 0.839625 (0.007887)
# LDA: 0.970000 (0.006374)
# SVM: 0.854000 (0.009598)
# NB: 0.502250 (0.043613)
# CART: 0.868000 (0.007250)
# LR: 0.857750 (0.010183)
# ScaledET: 0.895625 (0.009001)
# ScaledAB: 0.903625 (0.011625)
# ScaledRF: 0.895625 (0.011967)
# ScaledGBM: 0.901750 (0.010112)

# %% [markdown]
# ## 选定LDA作为模型

# %%
model = LinearDiscriminantAnalysis()
model.fit(X_train1,y_train1)

# 评估模型
prediction = model.predict(X_validation1)
accuracy_score(y_validation1,prediction)

# 保存模型
from pickle import dump
model_file = './csvs/liushi_predict.sav'
with open(model_file,'wb') as model_f:
    dump(model,model_f)
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#               solver='svd', store_covariance=False, tol=0.0001)
# 0.97499999999999998

# %% [markdown]
# ## 把其他模型也保存下来

# %%
modelab = AdaBoostClassifier()
modelab.fit(X_train1,y_train1)
model_fileab = './csvs/liushi_predict_AB.sav'
with open(model_fileab,'wb') as model_f:
    dump(modelab,model_f)
    
modelet = ExtraTreesClassifier()
modelet.fit(X_train1,y_train1)
model_fileet = './csvs/liushi_preidct_et.sav'
with open(model_fileet,'wb') as model_f:
    dump(modelet,model_f)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# ## 重新选取整个地方棋牌的10万条数据做测试
# 这次选取的是上上上周和上上周是否流失的对比哦

# %%
from pickle import load
path = './csvs/testfor_user_loss_predict.csv'
fiona_file_test = pd.read_csv(path,names=columns,skiprows=1)
#fiona_file_test.head(10)
# 数据处理
fiona_file_test = abs(fiona_file_test)
fiona_file_test.drop(['carrying_items_value','vip_level'],axis=1,inplace=True)
fiona_file_test.fillna(0,inplace=True)
# 将数据分为输入和输出
array = fiona_file_test.values
X2 = array[:,3:41]
y2 = array[:,2]

with open(model_file,'rb') as model_f:
    loaded_model = load(model_f)
    result = loaded_model.score(X2,y2)
    print("算法评估结果：%.3f%%"%(result*100))

with open(model_fileab,'rb') as model_f:
    loaded_model = load(model_f)
    result = loaded_model.score(X2,y2)
    print("算法评估结果：%.3f%%"%(result*100))

with open(model_fileet,'rb') as model_f:
    loaded_model = load(model_f)
    result = loaded_model.score(X2,y2)
    print("算法评估结果：%.3f%%"%(result*100))
# Out:
# 算法评估结果：83.478%
# 算法评估结果：91.903%
# 算法评估结果：91.136%

# %% [markdown]
# ## 嗯。。。准确性降到了83%，有没有可能这个模型只适用于云南地区呢？
# 让我们再选定云南地区的用户做测试

# %%
from pickle import load
path = './csvs/query-hive-14756.csv'
fiona_file_test = pd.read_csv(path,names=columns,skiprows=1)
#fiona_file_test.head(10)
# 数据处理
fiona_file_test = abs(fiona_file_test)
fiona_file_test.drop(['carrying_items_value','vip_level'],axis=1,inplace=True)
fiona_file_test.fillna(0,inplace=True)
# 将数据分为输入和输出
array = fiona_file_test.values
X2 = array[:,3:41]
y2 = array[:,2]

with open(model_file,'rb') as model_f:
    loaded_model = load(model_f)
    result = loaded_model.score(X2,y2)
    print("算法评估结果：%.3f%%"%(result*100))

with open(model_fileab,'rb') as model_f:
    loaded_model = load(model_f)
    result = loaded_model.score(X2,y2)
    print("算法评估结果：%.3f%%"%(result*100))

with open(model_fileet,'rb') as model_f:
    loaded_model = load(model_f)
    result = loaded_model.score(X2,y2)
    print("算法评估结果：%.3f%%"%(result*100))
# Out:
# 算法评估结果：94.531%
# 算法评估结果：89.684%
# 算法评估结果：89.572%

# %% [markdown]
# ##
